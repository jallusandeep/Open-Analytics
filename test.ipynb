# %%
import requests
import upstox_client
from upstox_client.rest import ApiException

ACCESS_TOKEN = "eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiI1UkNQUDIiLCJqdGkiOiI2YTIxMWJhN2I5ODBmNTJiZTA4NmE5OTkiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6dHJ1ZSwiaWF0IjoxNzgwNTU0NjYzLCJpc3MiOiJ1ZGFwaS1nYXRld2F5LXNlcnZpY2UiLCJleHAiOjE3ODA2MTA0MDB9.26go3YrPSZZWiDTj701Hszz1OVkAO8Fc-n5Bdt5Z2eQ"


headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {ACCESS_TOKEN}",
    "Accept": "application/json"
}

# Exact URL from Upstox docs — do NOT change anything
url = "https://api.upstox.com/v2/expired-instruments/expiries?instrument_key=NSE_INDEX%7CNifty%2050"

r = requests.get(url, headers=headers)
print("Status:", r.status_code)
print("Response:", r.json())
# Out:
# Status: 200
# ...
